# %%
# !nvidia-smi
# Out:
# Thu Sep  4 13:25:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics

# %%
import os
HOME = os.getcwd()
print(HOME)
import torch
# Out:
# /content

# %%
from ultralytics import YOLO

# %%
model = YOLO('yolo12n.pt')  # for training from scratch

# %%
model = YOLO('/content/yolo12n_new.yaml')
model.info(verbose=True)
# Out:
# YOLO12n_new summary: 115 layers, 1,849,616 parameters, 1,849,600 gradients, 7.8 GFLOPs
# (115, 1849616, 1849600, 7.817728000000001)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="EbeXKCB88EoSVGSt497X")
project = rf.workspace("mtech-yi2na").project("driver-distraction_single-camera")
version = project.version(5)
dataset = version.download("yolov12")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.6/88.6 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 106.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Driver-Distraction_Single-Camera-5 in yolov12:: 100%|██████████| 10842/10842 [00:01<00:00, 7401.29it/s]

# %%
model.train(data="/content/Driver-Distraction_Single-Camera-5/data.yaml", epochs=100, batch=16)
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/yolo12n.pt")  # load an official model
model = YOLO("/content/runs/detect/train/weights/best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map  # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps  # a list contains map50-95 of each category
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO12n_new summary (fused): 65 layers, 1,720,235 parameters, 0 gradients, 7.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1225.0±406.3 MB/s, size: 40.1 KB)
# val: Scanning /content/Driver-Distraction_Single-Camera-5/valid/labels.cache... 1078 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1078/1078 1.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 68/68 6.0it/s 11.3s
#                    all       1078       3455      0.855      0.883      0.915      0.613
#               Drinking        144        144      0.846      0.861      0.903      0.605
#                 Driver        823        823      0.969      0.995      0.991      0.767
#    Driver Looking away        118        118      0.889      0.941       0.97      0.743
# ...

# %%
# !yolo predict model="/content/runs/detect/train/weights/best.pt" source="/content/Driver-Distraction_Single-Camera-5/test/images"
# Out:
# Ultralytics 8.3.193 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO12n_new summary (fused): 65 layers, 1,720,235 parameters, 0 gradients, 7.1 GFLOPs
#
# image 1/550 /content/Driver-Distraction_Single-Camera-5/test/images/5_6312304681787852795_mp4-113_jpg.rf.4d2a628101ac24311d4dbee1a29cca54.jpg: 640x640 1 Driver Looking away, 2 Seat Belts, 9.5ms
# image 2/550 /content/Driver-Distraction_Single-Camera-5/test/images/5_6312304681787852795_mp4-116_jpg.rf.a924f8d7f2934d4743fa81286c3073fa.jpg: 640x640 1 Driver Looking away, 2 Seat Belts, 6.1ms
# image 3/550 /content/Driver-Distraction_Single-Camera-5/test/images/5_6312304681787852795_mp4-118_jpg.rf.e49395b70784a206c1dc17e2778c6f9f.jpg: 640x640 1 Driver Looking away, 2 Seat Belts, 6.1ms
# image 4/550 /content/Driver-Distraction_Single-Camera-5/test/images/5_6312304681787852795_mp4-126_jpg.rf.0acf8afc1faa54759e0ff2ae33595c20.jpg: 640x640 1 Driver Looking away, 2 Seat Belts, 6.0ms
# ...
